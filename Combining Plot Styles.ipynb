# %%
#Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# Stats imports
from scipy import stats

#Plotting imports
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(100)

# %%
#distplot allows combining plots
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False) #showing rug, not showing histogram

# %%
sns.distplot(dataset,bins=25,
             kde_kws = {'color':'indianred','label':'KDE PLOT'},
             hist_kws = {'color':'blue','label':'HIST'})

# %%
from pandas import Series
ser1 = Series(dataset,name='My_data')
ser1
# Out:
# 0    -0.024146
# 1    -1.340878
# 2    -2.168698
# 3     3.086485
# 4     0.496625
# 5     0.578333
# 6    -0.252117
# 7     1.273112
# 8    -0.888473
# 9     0.560699
# 10   -0.917805
# 11   -0.013095
# 12   -1.185109
# 13    0.305444
# 14    0.297548
# 15    0.446383
# 16    0.034088
# 17   -0.950818
# 18    1.601176
# 19   -0.581741
# 20   -0.789734
# 21    1.605375
# 22    0.906611
# 23   -0.520871
# 24    0.357049
# 25    0.929818
# 26   -1.234190
# 27   -1.789068
# 28   -0.064812
# 29   -1.078471
#         ...
# 70   -0.309359
# 71    0.617720
# 72    0.892608
# 73    0.049137
# 74    0.545978
# 75    0.215531
# 76    0.725540
# 77   -1.563561
# 78    0.360432
# 79   -0.903352
# 80   -0.610385
# 81   -1.997008
# 82    0.222336
# 83   -0.812493
# 84   -0.115765
# 85   -1.279089
# 86    0.052163
# 87   -0.247523
# 88    0.866739
# 89    0.688247
# 90    1.283011
# 91   -0.102031
# 92    0.361320
# 93    0.567064
# 94   -0.650287
# 95    1.025443
# 96   -1.630231
# 97    2.267388
# 98    1.264134
# 99   -0.531166
# Name: My_data, dtype: float64

# %%
sns.distplot(ser1,bins=25)
